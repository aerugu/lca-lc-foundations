# %% [markdown]
# ## Basic prompting

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from langchain.agents import create_agent
from langchain.messages import HumanMessage

agent = create_agent(model="claude-sonnet-4-6")

question = HumanMessage(content="What's the capital of the moon?")

response = agent.invoke(
    {"messages": [question]}
)

print(response['messages'][1].content)
# Out:
# The moon doesn't have a capital city. It has no permanent human settlements or government. There are only a few scientific instruments and artifacts left by past missions, such as the Apollo landing sites. As of now, no humans live on the moon.

# %%
system_prompt = "You are a science fiction writer, create a capital city at the users request."

scifi_agent = create_agent(
    model="claude-sonnet-4-6",
    system_prompt=system_prompt
)

response = scifi_agent.invoke(
    {"messages": [question]}
)

print(response['messages'][1].content)
# Out:
# # Selene City
#
# **Official Name:** Selene City (formerly Lunar Base Alpha)
# **Population:** 847,000
# **Established:** 2089
# **Location:** Mare Tranquillitatis (Sea of Tranquility) — a deliberate nod to the Apollo 11 landing site nearby
#
# ---
#
# ## Overview
#
# Selene City sprawls beneath a network of **interconnected geodesic domes**, some reaching 300 meters in height, giving residents sweeping views of the stark lunar landscape and the ever-present blue marble of Earth hanging in the black sky.
#
# ## Key Districts
#
# - **The Crater Quarter** — the oldest section, built partly underground for radiation shielding, now a historic and artistic neighborhood
# - **High Dome** — the gleaming governmental and commercial center
# - **The Gardens** — massive hydroponic parks providing food, oxygen, and desperately needed greenery
# - **Earthview Boulevard** — the most expensive real estate, facing Earth
#
# ## Notable Features
#
# - The **Tranquility Memorial** marks the original Apollo 11 landing site
# - Gravity is 1/6 Earth normal, making architecture *wonderfully* strange and tall
# - The city runs on **solar and helium-3 fusion power**
# - Residents are called **Selenites**
#
# ---
#
# *Want me to develop the politics, culture, or history further?*

# %% [markdown]
# ## Few-shot examples

# %%
system_prompt = """

You are a science fiction writer, create a space capital city at the users request.

User: What is the capital of mars?
Scifi Writer: Marsialis

User: What is the capital of Venus?
Scifi Writer: Venusovia

"""

scifi_agent = create_agent(
    model="claude-sonnet-4-6",
    system_prompt=system_prompt
)

response = scifi_agent.invoke(
    {"messages": [question]}
)

print(response['messages'][1].content)
# Out:
# Scifi Writer: Lunaris Prime
#
# *Lunaris Prime is a sprawling domed metropolis nestled within the Tycho crater, its massive transparent titanium domes offering breathtaking views of the starfield above and the distant blue marble of Earth. The city is built across multiple levels, with the lower districts carved deep into the lunar rock, and the upper tiers rising toward the dome ceiling in a glittering cascade of silver spires and illuminated walkways. It serves as the central hub of all lunar commerce, governance, and culture, home to over 2 million residents from dozens of Earth nations.*

# %% [markdown]
# ## Structured prompts

# %%
system_prompt = """

You are a science fiction writer, create a space capital city at the users request.

Please keep to the below structure.

Name: The name of the capital city

Location: Where it is based

Vibe: 2-3 words to describe its vibe

Economy: Main industries

"""

scifi_agent = create_agent(
    model="claude-sonnet-4-6",
    system_prompt=system_prompt
)

response = scifi_agent.invoke(
    {"messages": [question]}
)

print(response['messages'][1].content)
# Out:
# # Selene City
#
# **Name:** Selene City
#
# **Location:** Shackleton Crater, South Pole of the Moon — built into and around the crater's permanently shadowed rim, harnessing its peaks of eternal sunlight for solar power while mining ice deposits below.
#
# **Vibe:** Utilitarian, Frontier, Hopeful
#
# **Economy:**
# - **Helium-3 Mining** — exported across the solar system as clean fusion fuel
# - **Water Ice Processing** — essential for drinking, oxygen production, and rocket propellant
# - **Research & Science** — home to dozens of Earth-nation observatory institutions and university outposts
# - **Transit Hub** — serves as the primary layover and refueling port between Earth and the outer solar system

# %% [markdown]
# ## Structured output

# %%
from langchain.agents import create_agent
from langchain.messages import HumanMessage
from pydantic import BaseModel

class CapitalInfo(BaseModel):
    name: str
    location: str
    vibe: str
    economy: str

agent = create_agent(
    model='claude-sonnet-4-6',
    system_prompt="You are a science fiction writer, create a capital city at the users request.",
    response_format=CapitalInfo
)

question = HumanMessage(content="What is the capital of The Moon?")

response = agent.invoke(
    {"messages": [question]}
)

response["structured_response"]
# Out:
# CapitalInfo(name='Selene City', location='Nestled within the vast crater basin of Tycho on the lunar southern highlands, protected by towering ancient rim walls that shield it from solar radiation and micrometeorite impacts', vibe='A domed metropolis of gleaming titanium and transparent aluminum, where Earth hangs perpetually in the black sky like a blue marble artwork. The city pulses with a quiet, contemplative energy — colonists move with deliberate grace in the low gravity, philosophy cafes abound, and the two-week-long lunar nights inspire a culture of deep introspection and stargazing festivals', economy='Driven by Helium-3 mining and export to Earth-based fusion reactors, supplemented by rare earth mineral extraction, cutting-edge low-gravity pharmaceutical manufacturing, and a booming astrotourism industry catering to wealthy Earthers seeking the ultimate off-world experience')

# %%
response["structured_response"].name
# Out:
# 'Selene City'

# %%
capital_info = response["structured_response"]

capital_name = capital_info.name
capital_location = capital_info.location

print(f"{capital_name} is a city located at {capital_location}")
# Out:
# Selene City is a city located at Nestled within the vast crater basin of Tycho on the lunar southern highlands, protected by towering ancient rim walls that shield it from solar radiation and micrometeorite impacts
