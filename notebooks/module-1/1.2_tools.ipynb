# %% [markdown]
# ## Tool definition

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from langchain.tools import tool

@tool
def square_root(x: float) -> float:
    """Calculate the square root of a number"""
    return x ** 0.5

# %%
@tool("square_root")
def tool1(x: float) -> float:
    """Calculate the square root of a number"""
    return x ** 0.5

# %%
@tool("square_root", description="Calculate the square root of a number")
def tool1(x: float) -> float:
    return x ** 0.5

# %%
tool1.invoke({"x": 467})
# Out:
# 21.61018278497431

# %% [markdown]
# ## Adding to agents

# %%
from langchain.agents import create_agent

agent = create_agent(
    model="claude-sonnet-4-6",
    tools=[tool1],
    system_prompt="You are an arithmetic wizard. Use your tools to calculate the square root and square of any number."
)

# %%
from langchain.messages import HumanMessage

question = HumanMessage(content="What is the square root of 467?")

response = agent.invoke(
    {"messages": [question]}
)

print(response['messages'][-1].content)
# Out:
# The square root of **467** is approximately **21.6102**! 🧙‍♂️

# %%
from pprint import pprint

pprint(response['messages'])
# Out:
# [HumanMessage(content='What is the square root of 467?', additional_kwargs={}, response_metadata={}, id='4cf28123-84ad-41c9-81ea-232386460261'),
#  AIMessage(content=[{'text': 'Let me calculate that for you right away!', 'type': 'text'}, {'id': 'toolu_01A16ynbM9toeUjmftxPByaD', 'caller': {'type': 'direct'}, 'input': {'x': 467}, 'name': 'square_root', 'type': 'tool_use'}], additional_kwargs={}, response_metadata={'id': 'msg_011Cf9ZxoFkdy7uRd3E9grew', 'container': None, 'model': 'claude-sonnet-4-6', 'stop_details': None, 'stop_reason': 'tool_use', 'stop_sequence': None, 'usage': {'cache_creation': {'ephemeral_1h_input_tokens': 0, 'ephemeral_5m_input_tokens': 0}, 'cache_creation_input_tokens': 0, 'cache_read_input_tokens': 0, 'inference_geo': 'global', 'input_tokens': 589, 'output_tokens': 63, 'output_tokens_details': None, 'server_tool_use': None, 'service_tier': 'standard'}, 'model_name': 'claude-sonnet-4-6', 'model_provider': 'anthropic'}, id='lc_run--01a0b0db-1e97-7e21-8b76-c13b8e2494b7-0', tool_calls=[{'name': 'square_root', 'args': {'x': 467}, 'id': 'toolu_01A16ynbM9toeUjmftxPByaD', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 589, 'output_tokens': 63, 'total_tokens': 652, 'input_token_details': {'cache_read': 0, 'cache_creation': 0, 'ephemeral_5m_input_tokens': 0, 'ephemeral_1h_input_tokens': 0}}),
#  ToolMessage(content='21.61018278497431', name='square_root', id='d483c7cd-fdfd-4906-abbf-a883ed741ed6', tool_call_id='toolu_01A16ynbM9toeUjmftxPByaD'),
#  AIMessage(content='The square root of **467** is approximately **21.6102**! 🧙\u200d♂️', additional_kwargs={}, response_metadata={'id': 'msg_011Cf9ZxvBiTy2NJ1MnhEu9S', 'container': None, 'model': 'claude-sonnet-4-6', 'stop_details': None, 'stop_reason': 'end_turn', 'stop_sequence': None, 'usage': {'cache_creation': {'ephemeral_1h_input_tokens': 0, 'ephemeral_5m_input_tokens': 0}, 'cache_creation_input_tokens': 0, 'cache_read_input_tokens': 0, 'inference_geo': 'global', 'input_tokens': 671, 'output_tokens': 28, 'output_tokens_details': None, 'server_tool_use': None, 'service_tier': 'standard'}, 'model_name': 'claude-sonnet-4-6', 'model_provider': 'anthropic'}, id='lc_run--01a0b0db-25b0-7850-9aa8-7ea2c9801ddf-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 671, 'output_tokens': 28, 'total_tokens': 699, 'input_token_details': {'cache_read': 0, 'cache_creation': 0, 'ephemeral_5m_input_tokens': 0, 'ephemeral_1h_input_tokens': 0}})]

# %%
print(response["messages"][1].tool_calls)
# Out:
# [{'name': 'square_root', 'args': {'x': 467}, 'id': 'toolu_01A16ynbM9toeUjmftxPByaD', 'type': 'tool_call'}]
