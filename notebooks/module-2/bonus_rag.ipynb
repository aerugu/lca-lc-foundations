# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %% [markdown]
# ## Semantic search

# %%
from langchain_community.document_loaders import PyPDFLoader

loader = PyPDFLoader("resources/acmecorp-employee-handbook.pdf")

data = loader.load()

print(data)
# Out:
# /var/folders/sg/gdcf_tt93wx14p3rnv0kn57c0000gn/T/ipykernel_74764/4167041359.py:1: DeprecationWarning: `langchain-community` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-community/issues/674 for details and migration guidance toward standalone integration packages.
#   from langchain_community.document_loaders import PyPDFLoader
# [Document(metadata={'producer': 'ReportLab PDF Library - www.reportlab.com', 'creator': '(unspecified)', 'creationdate': '2025-11-20T23:23:16+00:00', 'author': '(anonymous)', 'keywords': '', 'moddate': '2025-11-20T23:23:16+00:00', 'subject': '(unspecified)', 'title': '(anonymous)', 'trapped': '/False', 'source': 'resources/acmecorp-employee-handbook.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1'}, page_content='Employee Handbook\nNon-Disclosure Agreement (NDA) Policy\nEmployees must protect confidential information belonging to the company, its clients, and partners.\nThis includes, but is not limited to, product roadmaps, customer data, internal communications,\nproprietary algorithms, financial information, and unreleased features. Confidential information may not\nbe shared with unauthorized individuals inside or outside the organization. These obligations continue\nafter employment ends.\nWorkplace Conduct Policy\nEmployees must maintain a respectful, professional environment free from harassment, discrimination,\nand intimidation. All employees are expected to follow organizational values, collaborate effectively,\nand communicate constructively. Disruptive behavior, verbal abuse, or misuse of company systems is\nprohibited. Violations may result in disciplinary action.\nPaid Time Off (PTO) Policy\nFull■time employees accrue PTO according to the following schedule: \x7f 0–1 years of service: 10 days\nper year (0.833 days per month) \x7f 1–3 years of service: 15 days per year (1.25 days per month) \x7f 3+\nyears of service: 20 days per year (1.67 days per month) PTO may be used for vacation, personal\nneeds, or illness. Requests should be submitted in advance through the HR system unless related to\nan emergency. Employees may carry over up to 5 unused PTO days per calendar year. Extended\nabsences exceeding 5 consecutive business days require manager approval.\nTravel & Expense Policy\nEmployees may be reimbursed for reasonable and necessary expenses incurred during approved\nbusiness travel. This includes transportation, lodging, meals, and incidental expenses within\nestablished limits. Receipts must be submitted within 14 days of travel. First-class travel, personal\nexpenses, and non-business activities are not reimbursable. Employees should exercise good\njudgment and cost-effective decision-making when traveling on behalf of the company.')]

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter

text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=1000, chunk_overlap=200, add_start_index=True
)
all_splits = text_splitter.split_documents(data)

print(len(all_splits))
# Out:
# 3

# %% [markdown]
# Embedding Models: https://docs.langchain.com/oss/python/integrations/text_embedding

# %%
from langchain_openai import OpenAIEmbeddings

embeddings = OpenAIEmbeddings(model="text-embedding-3-large")

# %%
from langchain_core.vectorstores import InMemoryVectorStore

vector_store = InMemoryVectorStore(embeddings)

# %%
ids = vector_store.add_documents(documents=all_splits)
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 ids = vector_store.add_documents(documents=all_splits)
#
# File ~/Documents/Full-Stack-GenAI/Agentic_AI/LangChain/lca-lc-foundations/.venv/lib/python3.13/site-packages/langchain_core/vectorstores/in_memory.py:195, in InMemoryVectorStore.add_documents(self, documents, ids, **kwargs)
#     187 @override
#     188 def add_documents(
#     189     self,
#    (...)    192     **kwargs: Any,
#     193 ) -> list[str]:
#     194     texts = [doc.page_content for doc in documents]
# --> 195     vectors = self.embedding.embed_documents(texts)
#     197     if ids and len(ids) != len(texts):
#     198         msg = (
#     199             f"ids must be the same length as texts. "
#     200             f"Got {len(ids)} ids and {len(texts)} texts."
#     201         )
#
# File ~/Documents/Full-Stack-GenAI/Agentic_AI/LangChain/lca-lc-foundations/.venv/lib/python3.13/site-packages/langchain_openai/embeddings/base.py:755, in OpenAIEmbeddings.embed_documents(self, texts, chunk_size, **kwargs)
#     752 # Unconditionally call _get_len_safe_embeddings to handle length safety.
#     753 # This could be optimized to avoid double work when all texts are short enough.
#     754 engine = cast(str, self.deployment)
# --> 755 return self._get_len_safe_embeddings(
#     756     texts, engine=engine, chunk_size=chunk_size, **kwargs
#     757 )
#
# File ~/Documents/Full-Stack-GenAI/Agentic_AI/LangChain/lca-lc-foundations/.venv/lib/python3.13/site-packages/langchain_openai/embeddings/base.py:622, in OpenAIEmbeddings._get_len_safe_embeddings(self, texts, engine, chunk_size, **kwargs)
#     620 # Make API call with this batch
#     621 batch_tokens = tokens[i:batch_end]
# --> 622 response = self.client.create(input=batch_tokens, **client_kwargs)
#     623 if not isinstance(response, dict):
#     624     response = response.model_dump()
#
# File ~/Documents/Full-Stack-GenAI/Agentic_AI/LangChain/lca-lc-foundations/.venv/lib/python3.13/site-packages/openai/resources/embeddings.py:136, in Embeddings.create(self, input, model, dimensions, encoding_format, user, extra_headers, extra_query, extra_body, timeout)
#     130             embedding.embedding = np.frombuffer(  # type: ignore[no-untyped-call]
#     131                 base64.b64decode(data), dtype="float32"
#     132             ).tolist()
#     134     return obj
# --> 136 return self._post(
#     137     "/embeddings",
#     138     body=maybe_transform(params, embedding_create_params.EmbeddingCreateParams),
#     139     options=make_request_options(
#     140         extra_headers=extra_headers,
#     141         extra_query=extra_query,
#     142         extra_body=extra_body,
#     143         timeout=timeout,
#     144         post_parser=parser,
#     145         security={"bearer_auth": True},
#     146     ),
#     147     cast_to=CreateEmbeddingResponse,
#     148 )
#
# File ~/Documents/Full-Stack-GenAI/Agentic_AI/LangChain/lca-lc-foundations/.venv/lib/python3.13/site-packages/openai/_base_client.py:1375, in SyncAPIClient.post(self, path, cast_to, body, content, options, files, stream, stream_cls)
#    1366     warnings.warn(
#    1367         "Passing raw bytes as `body` is deprecated and will be removed in a future version. "
#    1368         "Please pass raw bytes via the `content` parameter instead.",
#    1369         DeprecationWarning,
#    1370         stacklevel=2,
#    1371     )
#    1372 opts = FinalRequestOptions.construct(
#    1373     method="post", url=path, json_data=body, content=content, files=to_httpx_files(files), **options
#    1374 )
# -> 1375 return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~/Documents/Full-Stack-GenAI/Agentic_AI/LangChain/lca-lc-foundations/.venv/lib/python3.13/site-packages/openai/_base_client.py:1148, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1145             err.response.read()
#    1147         log.debug("Re-raising status error")
# -> 1148         raise self._make_status_error_from_response(err.response) from None
#    1150     break
#    1152 assert response is not None, "could not resolve response (should never happen)"
#
# RateLimitError: Error code: 429 - {'error': {'message': 'You have no credits remaining. Add credits to continue using the API at https://platform.openai.com/settings/organization/billing/.', 'type': 'insufficient_quota', 'param': None, 'code': 'credit_balance_exhausted'}}

# %%
results = vector_store.similarity_search(
    "How many days of vacation does an employee get in their first year?"
)

print(results[0])
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 results = vector_store.similarity_search(
#       2     "How many days of vacation does an employee get in their first year?"
#       3 )
#       4
#
# File ~/Documents/Full-Stack-GenAI/Agentic_AI/LangChain/lca-lc-foundations/.venv/lib/python3.13/site-packages/langchain_core/vectorstores/in_memory.py:407, in InMemoryVectorStore.similarity_search(self, query, k, **kwargs)
#     403 @override
#     404 def similarity_search(
#     405     self, query: str, k: int = 4, **kwargs: Any
#     406 ) -> list[Document]:
# --> 407     return [doc for doc, _ in self.similarity_search_with_score(query, k, **kwargs)]
#
# File ~/Documents/Full-Stack-GenAI/Agentic_AI/LangChain/lca-lc-foundations/.venv/lib/python3.13/site-packages/langchain_core/vectorstores/in_memory.py:365, in InMemoryVectorStore.similarity_search_with_score(self, query, k, **kwargs)
#     358 @override
#     359 def similarity_search_with_score(
#     360     self,
#    (...)    363     **kwargs: Any,
#     364 ) -> list[tuple[Document, float]]:
# --> 365     embedding = self.embedding.embed_query(query)
#     366     return self.similarity_search_with_score_by_vector(
#     367         embedding,
#     368         k,
#     369         **kwargs,
#     370     )
#
# File ~/Documents/Full-Stack-GenAI/Agentic_AI/LangChain/lca-lc-foundations/.venv/lib/python3.13/site-packages/langchain_openai/embeddings/base.py:805, in OpenAIEmbeddings.embed_query(self, text, **kwargs)
#     795 """Call out to OpenAI's embedding endpoint for embedding query text.
#     796
#     797 Args:
#    (...)    802     Embedding for the text.
#     803 """
#     804 self._ensure_sync_client_available()
# --> 805 return self.embed_documents([text], **kwargs)[0]
#
# File ~/Documents/Full-Stack-GenAI/Agentic_AI/LangChain/lca-lc-foundations/.venv/lib/python3.13/site-packages/langchain_openai/embeddings/base.py:755, in OpenAIEmbeddings.embed_documents(self, texts, chunk_size, **kwargs)
#     752 # Unconditionally call _get_len_safe_embeddings to handle length safety.
#     753 # This could be optimized to avoid double work when all texts are short enough.
#     754 engine = cast(str, self.deployment)
# --> 755 return self._get_len_safe_embeddings(
#     756     texts, engine=engine, chunk_size=chunk_size, **kwargs
#     757 )
#
# File ~/Documents/Full-Stack-GenAI/Agentic_AI/LangChain/lca-lc-foundations/.venv/lib/python3.13/site-packages/langchain_openai/embeddings/base.py:622, in OpenAIEmbeddings._get_len_safe_embeddings(self, texts, engine, chunk_size, **kwargs)
#     620 # Make API call with this batch
#     621 batch_tokens = tokens[i:batch_end]
# --> 622 response = self.client.create(input=batch_tokens, **client_kwargs)
#     623 if not isinstance(response, dict):
#     624     response = response.model_dump()
#
# File ~/Documents/Full-Stack-GenAI/Agentic_AI/LangChain/lca-lc-foundations/.venv/lib/python3.13/site-packages/openai/resources/embeddings.py:136, in Embeddings.create(self, input, model, dimensions, encoding_format, user, extra_headers, extra_query, extra_body, timeout)
#     130             embedding.embedding = np.frombuffer(  # type: ignore[no-untyped-call]
#     131                 base64.b64decode(data), dtype="float32"
#     132             ).tolist()
#     134     return obj
# --> 136 return self._post(
#     137     "/embeddings",
#     138     body=maybe_transform(params, embedding_create_params.EmbeddingCreateParams),
#     139     options=make_request_options(
#     140         extra_headers=extra_headers,
#     141         extra_query=extra_query,
#     142         extra_body=extra_body,
#     143         timeout=timeout,
#     144         post_parser=parser,
#     145         security={"bearer_auth": True},
#     146     ),
#     147     cast_to=CreateEmbeddingResponse,
#     148 )
#
# File ~/Documents/Full-Stack-GenAI/Agentic_AI/LangChain/lca-lc-foundations/.venv/lib/python3.13/site-packages/openai/_base_client.py:1375, in SyncAPIClient.post(self, path, cast_to, body, content, options, files, stream, stream_cls)
#    1366     warnings.warn(
#    1367         "Passing raw bytes as `body` is deprecated and will be removed in a future version. "
#    1368         "Please pass raw bytes via the `content` parameter instead.",
#    1369         DeprecationWarning,
#    1370         stacklevel=2,
#    1371     )
#    1372 opts = FinalRequestOptions.construct(
#    1373     method="post", url=path, json_data=body, content=content, files=to_httpx_files(files), **options
#    1374 )
# -> 1375 return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~/Documents/Full-Stack-GenAI/Agentic_AI/LangChain/lca-lc-foundations/.venv/lib/python3.13/site-packages/openai/_base_client.py:1148, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1145             err.response.read()
#    1147         log.debug("Re-raising status error")
# -> 1148         raise self._make_status_error_from_response(err.response) from None
#    1150     break
#    1152 assert response is not None, "could not resolve response (should never happen)"
#
# RateLimitError: Error code: 429 - {'error': {'message': 'You have no credits remaining. Add credits to continue using the API at https://platform.openai.com/settings/organization/billing/.', 'type': 'insufficient_quota', 'param': None, 'code': 'credit_balance_exhausted'}}

# %% [markdown]
# ## RAG Agent

# %%
from langchain.tools import tool

@tool
def search_handbook(query: str) -> str:
    """Search the employee handbook for information"""
    results = vector_store.similarity_search(query)
    return results[0].page_content

# %%
from langchain.agents import create_agent

agent = create_agent(
    model="gpt-5-nano",
    tools=[search_handbook],
    system_prompt="You are a helpful agent that can search the employee handbook for information."
    )

# %%
from langchain.messages import HumanMessage

response = agent.invoke(
    {"messages": [HumanMessage(content="How many days of vacation does an employee get in their first year?")]}
)
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[10], line 3
#       1 from langchain.messages import HumanMessage
#       2
# ----> 3 response = agent.invoke(
#       4     {"messages": [HumanMessage(content="How many days of vacation does an employee get in their first year?")]}
#       5 )
#
# File ~/Documents/Full-Stack-GenAI/Agentic_AI/LangChain/lca-lc-foundations/.venv/lib/python3.13/site-packages/langgraph/pregel/main.py:3913, in Pregel.invoke(self, input, config, context, stream_mode, print_mode, output_keys, interrupt_before, interrupt_after, durability, control, version, **kwargs)
#    3910             chunks.append(chunk)
#    3911 else:
#    3912     # v1: collect interrupts from updates stream
# -> 3913     for chunk in self.stream(
#    3914         input,
#    3915         config,
#    3916         context=context,
#    3917         stream_mode=(
#    3918             ["updates", "values"] if stream_mode == "values" else stream_mode
#    3919         ),
#    3920         print_mode=print_mode,
#    3921         output_keys=output_keys,
#    3922         interrupt_before=interrupt_before,
#    3923         interrupt_after=interrupt_after,
#    3924         durability=durability,
#    3925         control=control,
#    3926         **kwargs,
#    3927     ):
#    3928         if stream_mode == "values":
#    3929             if len(chunk) == 2:
#
# File ~/Documents/Full-Stack-GenAI/Agentic_AI/LangChain/lca-lc-foundations/.venv/lib/python3.13/site-packages/langgraph/pregel/main.py:2967, in Pregel.stream(self, input, config, context, stream_mode, print_mode, output_keys, interrupt_before, interrupt_after, durability, control, subgraphs, debug, version, **kwargs)
#    2965 for task in loop.match_cached_writes():
#    2966     loop.output_writes(task.id, task.writes, cached=True)
# -> 2967 for _ in runner.tick(
#    2968     [t for t in loop.tasks.values() if not t.writes],
#    2969     timeout=self.step_timeout,
#    2970     get_waiter=get_waiter,
#    2971     schedule_task=loop.accept_push,
#    2972 ):
#    2973     # emit output
#    2974     yield from _output(
#    2975         stream_mode,
#    2976         print_mode,
#    (...)   2982         _state_mapper,
#    2983     )
#    2984 loop.after_tick()
#
# File ~/Documents/Full-Stack-GenAI/Agentic_AI/LangChain/lca-lc-foundations/.venv/lib/python3.13/site-packages/langgraph/pregel/_runner.py:207, in PregelRunner.tick(self, tasks, reraise, timeout, retry_policy, get_waiter, schedule_task)
#     205 scheduled_error_handler = False
#     206 try:
# --> 207     run_with_retry(
#     208         t,
#     209         retry_policy,
#     210         configurable={
#     211             CONFIG_KEY_CALL: partial(
#     212                 _call,
#     213                 weakref.ref(t),
#     214                 retry_policy=retry_policy,
#     215                 futures=weakref.ref(futures),
#     216                 schedule_task=schedule_task,
#     217                 submit=self.submit,
#     218             ),
#     219         },
#     220     )
#     221     self.commit(t, None)
#     222 except Exception as exc:
#
# File ~/Documents/Full-Stack-GenAI/Agentic_AI/LangChain/lca-lc-foundations/.venv/lib/python3.13/site-packages/langgraph/pregel/_retry.py:617, in run_with_retry(task, retry_policy, configurable)
#     615     task.writes.clear()
#     616     # run the task
# --> 617     return task.proc.invoke(task.input, config)
#     618 except ParentCommand as exc:
#     619     ns: str = config[CONF][CONFIG_KEY_CHECKPOINT_NS]
#
# File ~/Documents/Full-Stack-GenAI/Agentic_AI/LangChain/lca-lc-foundations/.venv/lib/python3.13/site-packages/langgraph/_internal/_runnable.py:684, in RunnableSeq.invoke(self, input, config, **kwargs)
#     682     # run in context
#     683     with set_config_context(config, run) as context:
# --> 684         input = context.run(step.invoke, input, config, **kwargs)
#     685 else:
#     686     input = step.invoke(input, config)
#
# File ~/Documents/Full-Stack-GenAI/Agentic_AI/LangChain/lca-lc-foundations/.venv/lib/python3.13/site-packages/langgraph/_internal/_runnable.py:426, in RunnableCallable.invoke(self, input, config, **kwargs)
#     424         run_manager.on_chain_end(ret)
#     425 else:
# --> 426     ret = self.func(*args, **kwargs)
#     427 if self.recurse and isinstance(ret, Runnable):
#     428     return ret.invoke(input, config)
#
# File ~/Documents/Full-Stack-GenAI/Agentic_AI/LangChain/lca-lc-foundations/.venv/lib/python3.13/site-packages/langchain/agents/factory.py:1447, in create_agent.<locals>.model_node(state, runtime)
#    1435 request = ModelRequest(
#    1436     model=model,
#    1437     tools=default_tools,
#    (...)   1443     runtime=runtime,
#    1444 )
#    1446 if wrap_model_call_handler is None:
# -> 1447     model_response = _execute_model_sync(request)
#    1448     return _build_commands(model_response)
#    1450 result = wrap_model_call_handler(request, _execute_model_sync)
#
# File ~/Documents/Full-Stack-GenAI/Agentic_AI/LangChain/lca-lc-foundations/.venv/lib/python3.13/site-packages/langchain/agents/factory.py:1419, in create_agent.<locals>._execute_model_sync(request)
#    1416 if request.system_message:
#    1417     messages = [request.system_message, *messages]
# -> 1419 output = model_.invoke(messages)
#    1420 if name:
#    1421     output.name = name
#
# File ~/Documents/Full-Stack-GenAI/Agentic_AI/LangChain/lca-lc-foundations/.venv/lib/python3.13/site-packages/langchain_core/runnables/base.py:6002, in RunnableBindingBase.invoke(self, input, config, **kwargs)
#    5995 @override
#    5996 def invoke(
#    5997     self,
#    (...)   6000     **kwargs: Any | None,
#    6001 ) -> Output:
# -> 6002     return self.bound.invoke(
#    6003         input,
#    6004         self._merge_configs(config),
#    6005         **{**self.kwargs, **kwargs},
#    6006     )
#
# File ~/Documents/Full-Stack-GenAI/Agentic_AI/LangChain/lca-lc-foundations/.venv/lib/python3.13/site-packages/langchain_core/language_models/chat_models.py:476, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     462 @override
#     463 def invoke(
#     464     self,
#    (...)    469     **kwargs: Any,
#     470 ) -> AIMessage:
#     471     config = ensure_config(config)
#     472     return cast(
#     473         "AIMessage",
#     474         cast(
#     475             "ChatGeneration",
# --> 476             self.generate_prompt(
#     477                 [self._convert_input(input)],
#     478                 stop=stop,
#     479                 callbacks=config.get("callbacks"),
#     480                 tags=config.get("tags"),
#     481                 metadata=config.get("metadata"),
#     482                 run_name=config.get("run_name"),
#     483                 run_id=config.pop("run_id", None),
#     484                 **kwargs,
#     485             ).generations[0][0],
#     486         ).message,
#     487     )
#
# File ~/Documents/Full-Stack-GenAI/Agentic_AI/LangChain/lca-lc-foundations/.venv/lib/python3.13/site-packages/langchain_core/language_models/chat_models.py:1849, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#    1840 @override
#    1841 def generate_prompt(
#    1842     self,
#    (...)   1846     **kwargs: Any,
#    1847 ) -> LLMResult:
#    1848     prompt_messages = [p.to_messages() for p in prompts]
# -> 1849     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File ~/Documents/Full-Stack-GenAI/Agentic_AI/LangChain/lca-lc-foundations/.venv/lib/python3.13/site-packages/langchain_core/language_models/chat_models.py:1656, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#    1653 for i, m in enumerate(input_messages):
#    1654     try:
#    1655         results.append(
# -> 1656             self._generate_with_cache(
#    1657                 m,
#    1658                 stop=stop,
#    1659                 run_manager=run_managers[i] if run_managers else None,
#    1660                 **kwargs,
#    1661             )
#    1662         )
#    1663     except BaseException as e:
#    1664         if run_managers:
#
# File ~/Documents/Full-Stack-GenAI/Agentic_AI/LangChain/lca-lc-foundations/.venv/lib/python3.13/site-packages/langchain_core/language_models/chat_models.py:1994, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#    1992     result = generate_from_stream(iter(chunks))
#    1993 elif inspect.signature(self._generate).parameters.get("run_manager"):
# -> 1994     result = self._generate(
#    1995         messages, stop=stop, run_manager=run_manager, **kwargs
#    1996     )
#    1997 else:
#    1998     result = self._generate(messages, stop=stop, **kwargs)
#
# File ~/Documents/Full-Stack-GenAI/Agentic_AI/LangChain/lca-lc-foundations/.venv/lib/python3.13/site-packages/langchain_openai/chat_models/base.py:1747, in BaseChatOpenAI._generate(self, messages, stop, run_manager, **kwargs)
#    1745     _handle_openai_bad_request(e)
#    1746 except openai.APIError as e:
# -> 1747     _handle_openai_api_error(e)
#    1748 except Exception as e:
#    1749     if raw_response is not None and hasattr(raw_response, "http_response"):
#
# File ~/Documents/Full-Stack-GenAI/Agentic_AI/LangChain/lca-lc-foundations/.venv/lib/python3.13/site-packages/langchain_openai/chat_models/base.py:1742, in BaseChatOpenAI._generate(self, messages, stop, run_manager, **kwargs)
#    1735         return _construct_lc_result_from_responses_api(
#    1736             response,
#    1737             schema=original_schema_obj,
#    1738             metadata=generation_info,
#    1739             output_version=self.output_version,
#    1740         )
#    1741     else:
# -> 1742         raw_response = self.client.with_raw_response.create(**payload)
#    1743         response = raw_response.parse()
#    1744 except openai.BadRequestError as e:
#
# File ~/Documents/Full-Stack-GenAI/Agentic_AI/LangChain/lca-lc-foundations/.venv/lib/python3.13/site-packages/openai/_legacy_response.py:369, in to_raw_response_wrapper.<locals>.wrapped(*args, **kwargs)
#     365 extra_headers[RAW_RESPONSE_HEADER] = "true"
#     367 kwargs["extra_headers"] = extra_headers
# --> 369 return cast(LegacyAPIResponse[R], func(*args, **kwargs))
#
# File ~/Documents/Full-Stack-GenAI/Agentic_AI/LangChain/lca-lc-foundations/.venv/lib/python3.13/site-packages/openai/_utils/_utils.py:298, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     296             msg = f"Missing required argument: {quote(missing[0])}"
#     297     raise TypeError(msg)
# --> 298 return func(*args, **kwargs)
#
# File ~/Documents/Full-Stack-GenAI/Agentic_AI/LangChain/lca-lc-foundations/.venv/lib/python3.13/site-packages/openai/resources/chat/completions/completions.py:1296, in Completions.create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, moderation, n, parallel_tool_calls, prediction, presence_penalty, prompt_cache_key, prompt_cache_options, prompt_cache_retention, reasoning_effort, response_format, safety_identifier, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, verbosity, web_search_options, extra_headers, extra_query, extra_body, timeout)
#    1247 @required_args(["messages", "model"], ["messages", "model", "stream"])
#    1248 def create(
#    1249     self,
#    (...)   1293     timeout: float | httpx.Timeout | None | NotGiven = not_given,
#    1294 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#    1295     validate_response_format(response_format)
# -> 1296     return self._post(
#    1297         "/chat/completions",
#    1298         body=maybe_transform(
#    1299             {
#    1300                 "messages": messages,
#    1301                 "model": model,
#    1302                 "audio": audio,
#    1303                 "frequency_penalty": frequency_penalty,
#    1304                 "function_call": function_call,
#    1305                 "functions": functions,
#    1306                 "logit_bias": logit_bias,
#    1307                 "logprobs": logprobs,
#    1308                 "max_completion_tokens": max_completion_tokens,
#    1309                 "max_tokens": max_tokens,
#    1310                 "metadata": metadata,
#    1311                 "modalities": modalities,
#    1312                 "moderation": moderation,
#    1313                 "n": n,
#    1314                 "parallel_tool_calls": parallel_tool_calls,
#    1315                 "prediction": prediction,
#    1316                 "presence_penalty": presence_penalty,
#    1317                 "prompt_cache_key": prompt_cache_key,
#    1318                 "prompt_cache_options": prompt_cache_options,
#    1319                 "prompt_cache_retention": prompt_cache_retention,
#    1320                 "reasoning_effort": reasoning_effort,
#    1321                 "response_format": response_format,
#    1322                 "safety_identifier": safety_identifier,
#    1323                 "seed": seed,
#    1324                 "service_tier": service_tier,
#    1325                 "stop": stop,
#    1326                 "store": store,
#    1327                 "stream": stream,
#    1328                 "stream_options": stream_options,
#    1329                 "temperature": temperature,
#    1330                 "tool_choice": tool_choice,
#    1331                 "tools": tools,
#    1332                 "top_logprobs": top_logprobs,
#    1333                 "top_p": top_p,
#    1334                 "user": user,
#    1335                 "verbosity": verbosity,
#    1336                 "web_search_options": web_search_options,
#    1337             },
#    1338             completion_create_params.CompletionCreateParamsStreaming
#    1339             if stream
#    1340             else completion_create_params.CompletionCreateParamsNonStreaming,
#    1341         ),
#    1342         options=make_request_options(
#    1343             extra_headers=extra_headers,
#    1344             extra_query=extra_query,
#    1345             extra_body=extra_body,
#    1346             timeout=timeout,
#    1347             security={"bearer_auth": True},
#    1348         ),
#    1349         cast_to=ChatCompletion,
#    1350         stream=stream or False,
#    1351         stream_cls=Stream[ChatCompletionChunk],
#    1352     )
#
# File ~/Documents/Full-Stack-GenAI/Agentic_AI/LangChain/lca-lc-foundations/.venv/lib/python3.13/site-packages/openai/_base_client.py:1375, in SyncAPIClient.post(self, path, cast_to, body, content, options, files, stream, stream_cls)
#    1366     warnings.warn(
#    1367         "Passing raw bytes as `body` is deprecated and will be removed in a future version. "
#    1368         "Please pass raw bytes via the `content` parameter instead.",
#    1369         DeprecationWarning,
#    1370         stacklevel=2,
#    1371     )
#    1372 opts = FinalRequestOptions.construct(
#    1373     method="post", url=path, json_data=body, content=content, files=to_httpx_files(files), **options
#    1374 )
# -> 1375 return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~/Documents/Full-Stack-GenAI/Agentic_AI/LangChain/lca-lc-foundations/.venv/lib/python3.13/site-packages/openai/_base_client.py:1148, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1145             err.response.read()
#    1147         log.debug("Re-raising status error")
# -> 1148         raise self._make_status_error_from_response(err.response) from None
#    1150     break
#    1152 assert response is not None, "could not resolve response (should never happen)"
#
# RateLimitError: Error code: 429 - {'error': {'message': 'You have no credits remaining. Add credits to continue using the API at https://platform.openai.com/settings/organization/billing/.', 'type': 'insufficient_quota', 'param': None, 'code': 'credit_balance_exhausted'}}
# During task with name 'model' and id 'f88027d5-ff33-a0ee-c14b-9f555b7f4ebc'

# %%
from pprint import pprint

pprint(response)
