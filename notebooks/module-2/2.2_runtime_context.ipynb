# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from dataclasses import dataclass

@dataclass
class ColourContext:
    favourite_colour: str = "blue"
    least_favourite_colour: str = "yellow"

# %%
from langchain.agents import create_agent

agent = create_agent(
    model="claude-sonnet-4-6",
    context_schema=ColourContext  
)

# %%
from langchain.messages import HumanMessage

response = agent.invoke(
    {"messages": [HumanMessage(content="What is my favourite colour?")]},
    context=ColourContext()
)

# %%
from pprint import pprint

pprint(response)
# Out:
# {'messages': [HumanMessage(content='What is my favourite colour?', additional_kwargs={}, response_metadata={}, id='9ef58266-9465-4552-b527-fa7bb438f03f'),
#               AIMessage(content="I don't know your favourite colour! I don't have any personal information about you unless you share it with me. Would you like to tell me? 😊", additional_kwargs={}, response_metadata={'id': 'msg_011Cf9jkkXsTKU8BfSRfLwLh', 'container': None, 'model': 'claude-sonnet-4-6', 'stop_details': None, 'stop_reason': 'end_turn', 'stop_sequence': None, 'usage': {'cache_creation': {'ephemeral_1h_input_tokens': 0, 'ephemeral_5m_input_tokens': 0}, 'cache_creation_input_tokens': 0, 'cache_read_input_tokens': 0, 'inference_geo': 'global', 'input_tokens': 13, 'output_tokens': 37, 'output_tokens_details': None, 'server_tool_use': None, 'service_tier': 'standard'}, 'model_name': 'claude-sonnet-4-6', 'model_provider': 'anthropic'}, id='lc_run--01a0b150-af32-7ea0-b88b-081d32c8b3eb-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 13, 'output_tokens': 37, 'total_tokens': 50, 'input_token_details': {'cache_read': 0, 'cache_creation': 0, 'ephemeral_5m_input_tokens': 0, 'ephemeral_1h_input_tokens': 0}})]}

# %% [markdown]
# ## Accessing Context

# %%
from langchain.tools import tool, ToolRuntime

@tool
def get_favourite_colour(runtime: ToolRuntime[ColourContext]) -> str:
    """Get the favourite colour of the user"""
    return runtime.context.favourite_colour

@tool
def get_least_favourite_colour(runtime: ToolRuntime[ColourContext]) -> str:
    """Get the least favourite colour of the user"""
    return runtime.context.least_favourite_colour

# %%
agent = create_agent(
    model="claude-sonnet-4-6",
    tools=[get_favourite_colour, get_least_favourite_colour],
    context_schema=ColourContext
)

# %%
response = agent.invoke(
    {"messages": [HumanMessage(content="What is my favourite colour?")]},
    context=ColourContext()
)

pprint(response)
# Out:
# {'messages': [HumanMessage(content='What is my favourite colour?', additional_kwargs={}, response_metadata={}, id='20f4d0a5-43ee-4147-9a2c-b03c1fd6645e'),
#               AIMessage(content=[{'text': 'Let me look that up for you!', 'type': 'text'}, {'id': 'toolu_01HYyTo8qoYjc9RrdF6NsrFo', 'caller': {'type': 'direct'}, 'input': {}, 'name': 'get_favourite_colour', 'type': 'tool_use'}], additional_kwargs={}, response_metadata={'id': 'msg_011Cf9jreUfUjKHv96wAWKEz', 'container': None, 'model': 'claude-sonnet-4-6', 'stop_details': None, 'stop_reason': 'tool_use', 'stop_sequence': None, 'usage': {'cache_creation': {'ephemeral_1h_input_tokens': 0, 'ephemeral_5m_input_tokens': 0}, 'cache_creation_input_tokens': 0, 'cache_read_input_tokens': 0, 'inference_geo': 'global', 'input_tokens': 599, 'output_tokens': 47, 'output_tokens_details': None, 'server_tool_use': None, 'service_tier': 'standard'}, 'model_name': 'claude-sonnet-4-6', 'model_provider': 'anthropic'}, id='lc_run--01a0b151-e805-7892-8965-d0bca88f00a1-0', tool_calls=[{'name': 'get_favourite_colour', 'args': {}, 'id': 'toolu_01HYyTo8qoYjc9RrdF6NsrFo', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 599, 'output_tokens': 47, 'total_tokens': 646, 'input_token_details': {'cache_read': 0, 'cache_creation': 0, 'ephemeral_5m_input_tokens': 0, 'ephemeral_1h_input_tokens': 0}}),
#               ToolMessage(content='blue', name='get_favourite_colour', id='93225d8e-4e69-42f8-8e1c-69b384c46de0', tool_call_id='toolu_01HYyTo8qoYjc9RrdF6NsrFo'),
#               AIMessage(content='Your favourite colour is **blue**! 🔵', additional_kwargs={}, response_metadata={'id': 'msg_011Cf9js1KHgkkteFnURjMna', 'container': None, 'model': 'claude-sonnet-4-6', 'stop_details': None, 'stop_reason': 'end_turn', 'stop_sequence': None, 'usage': {'cache_creation': {'ephemeral_1h_input_tokens': 0, 'ephemeral_5m_input_tokens': 0}, 'cache_creation_input_tokens': 0, 'cache_read_input_tokens': 0, 'inference_geo': 'global', 'input_tokens': 659, 'output_tokens': 15, 'output_tokens_details': None, 'server_tool_use': None, 'service_tier': 'standard'}, 'model_name': 'claude-sonnet-4-6', 'model_provider': 'anthropic'}, id='lc_run--01a0b151-fb8b-7ea1-9756-5481329ae5fe-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 659, 'output_tokens': 15, 'total_tokens': 674, 'input_token_details': {'cache_read': 0, 'cache_creation': 0, 'ephemeral_5m_input_tokens': 0, 'ephemeral_1h_input_tokens': 0}})]}

# %%
response = agent.invoke(
    {"messages": [HumanMessage(content="What is my favourite colour?")]},
    context=ColourContext(favourite_colour="green")
)

pprint(response)
# Out:
# {'messages': [HumanMessage(content='What is my favourite colour?', additional_kwargs={}, response_metadata={}, id='fb33a6bf-d512-46bb-ae55-cf3a7bf9f7e3'),
#               AIMessage(content=[{'text': 'Let me look that up for you!', 'type': 'text'}, {'id': 'toolu_01She56x5S5eJPeZDZDVY2DD', 'caller': {'type': 'direct'}, 'input': {}, 'name': 'get_favourite_colour', 'type': 'tool_use'}], additional_kwargs={}, response_metadata={'id': 'msg_011Cf9jt1PHGctAAx3bjGVCy', 'container': None, 'model': 'claude-sonnet-4-6', 'stop_details': None, 'stop_reason': 'tool_use', 'stop_sequence': None, 'usage': {'cache_creation': {'ephemeral_1h_input_tokens': 0, 'ephemeral_5m_input_tokens': 0}, 'cache_creation_input_tokens': 0, 'cache_read_input_tokens': 0, 'inference_geo': 'global', 'input_tokens': 599, 'output_tokens': 47, 'output_tokens_details': None, 'server_tool_use': None, 'service_tier': 'standard'}, 'model_name': 'claude-sonnet-4-6', 'model_provider': 'anthropic'}, id='lc_run--01a0b152-3070-7903-bcf5-e6a2339e208e-0', tool_calls=[{'name': 'get_favourite_colour', 'args': {}, 'id': 'toolu_01She56x5S5eJPeZDZDVY2DD', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 599, 'output_tokens': 47, 'total_tokens': 646, 'input_token_details': {'cache_read': 0, 'cache_creation': 0, 'ephemeral_5m_input_tokens': 0, 'ephemeral_1h_input_tokens': 0}}),
#               ToolMessage(content='green', name='get_favourite_colour', id='fda4f199-cbba-4612-8057-a5c9c93ee0b4', tool_call_id='toolu_01She56x5S5eJPeZDZDVY2DD'),
#               AIMessage(content='Your favourite colour is **green**! 🟢', additional_kwargs={}, response_metadata={'id': 'msg_011Cf9jt99rHDNsSHQY5oUoX', 'container': None, 'model': 'claude-sonnet-4-6', 'stop_details': None, 'stop_reason': 'end_turn', 'stop_sequence': None, 'usage': {'cache_creation': {'ephemeral_1h_input_tokens': 0, 'ephemeral_5m_input_tokens': 0}, 'cache_creation_input_tokens': 0, 'cache_read_input_tokens': 0, 'inference_geo': 'global', 'input_tokens': 659, 'output_tokens': 15, 'output_tokens_details': None, 'server_tool_use': None, 'service_tier': 'standard'}, 'model_name': 'claude-sonnet-4-6', 'model_provider': 'anthropic'}, id='lc_run--01a0b152-375a-73c3-ba40-dec857bf7f92-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 659, 'output_tokens': 15, 'total_tokens': 674, 'input_token_details': {'cache_read': 0, 'cache_creation': 0, 'ephemeral_5m_input_tokens': 0, 'ephemeral_1h_input_tokens': 0}})]}
